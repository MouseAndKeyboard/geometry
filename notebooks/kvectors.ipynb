# %%
# %matplotlib widget

# %%
import sys
sys.path.append('../')

import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from discrete_diff_geo.k_vector import kVector

# %%
u = kVector(np.array([1, 2, 3, 4]))
v = kVector(np.array([4, 5, 6, 8]))
w = kVector(np.array([7, 8, 9, 10]))

result = u.wedge(v)
result
# Out:
# kVector(-3*e(0, 1) - 6*e(0, 2) - 8*e(0, 3) - 3*e(1, 2) - 4*e(1, 3))

# %%
result.wedge(w)
# Out:
# kVector(6*e(0, 1, 3) + 12*e(0, 2, 3) + 6*e(1, 2, 3))

# %% [markdown]
# # Visualisations

# %%
import matplotlib.pyplot as plt

# %%
from ipympl import _version
print(_version.version_info)
# Out:
# (0, 9, 3)

# %% [markdown]
# ## 2D

# %% [markdown]
# ### 1-Vectors

# %%
u = kVector(np.array([1, -2, 3]))


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax = u.plot(ax=ax)
fig.savefig("test.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 2-Vectors

# %%
u = kVector(np.array([1, -2, 3]))
v = kVector(np.array([3, 1]))
w = u.wedge(v)
w.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[170], line 3
#       1 u = kVector(np.array([1, -2, 3]))
#       2 v = kVector(np.array([3, 1]))
# ----> 3 w = u.wedge(v)
#       4 w.plot()
#
# File ~/projects/academy/reading/spivak/geometry/notebooks/../discrete_diff_geo/k_vector.py:59, in kVector.wedge(self, other)
#      56 def wedge(self, other):
#      58     if self.vector_dim != other.vector_dim:
# ---> 59         raise ValueError(f"Vectors must have the same dimension.")
#      61     new_k = self.k + other.k
#      63     new_k_vector = kVector(np.zeros(self.vector_dim))
#
# ValueError: Vectors must have the same dimension.

# %% [markdown]
# ## 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### 1-Vectors

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Assuming v is your vector
u = kVector(np.array([1, 2, 3]))
ax.quiver(0, 0, 0, u.get_coefficient((0,)), u.get_coefficient((1,)), u.get_coefficient((2,)))
ax.set_xlim([0, 3])
ax.set_ylim([0, 3])
ax.set_zlim([0, 3])
plt.show()

# %% [markdown]
# ### 2-Vectors

# %%
u = kVector(np.array([1, 2, 3]))
v = kVector(np.array([2, 1, 4]))

w = u.wedge(v)
w.plot()
